# %%
import numpy as np  
import pandas as pd  
import matplotlib.pyplot as plt   

# %matplotlib inline

# %%
sales = pd.read_csv('sales_data.csv', parse_dates=['Date'])

# %%
sales.head()  #information in head
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
sales.shape   #number columns and rows
# Out:
# (113036, 18)

# %%
sales.info()  #types in the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  datetime64[ns]
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
sales.describe()  #show stadistics' dataset
# Out:
#                                 Date            Day           Year  \
# count                         113036  113036.000000  113036.000000
# mean   2014-11-23 12:14:55.063519232      15.665753    2014.401739
# min              2011-01-01 00:00:00       1.000000    2011.000000
# 25%              2013-12-22 00:00:00       8.000000    2013.000000
# 50%              2014-06-27 00:00:00      16.000000    2014.000000
# 75%              2016-01-09 00:00:00      23.000000    2016.000000
# max              2016-07-31 00:00:00      31.000000    2016.000000
# std                              NaN       8.781567       1.272510
#
#         Customer_Age  Order_Quantity      Unit_Cost     Unit_Price  \
# count  113036.000000   113036.000000  113036.000000  113036.000000
# mean       35.919212       11.901660     267.296366     452.938427
# min        17.000000        1.000000       1.000000       2.000000
# 25%        28.000000        2.000000       2.000000       5.000000
# ...

# %%
sales['Unit_Cost'].describe()
# Out:
# count    113036.000000
# mean        267.296366
# std         549.835483
# min           1.000000
# 25%           2.000000
# 50%           9.000000
# 75%          42.000000
# max        2171.000000
# Name: Unit_Cost, dtype: float64

# %%
sales['Unit_Cost'].mean()
# Out:
# np.float64(267.296365759581)

# %%
sales['Unit_Cost'].median()
# Out:
# np.float64(9.0)

# %%
sales['Unit_Cost'].std()
# Out:
# np.float64(549.8354831075126)

# %%
sales['Unit_Cost'].max()
# Out:
# np.int64(2171)

# %%
sales['Unit_Cost'].plot(kind='box', vert=False, figsize=(14,6))   #chart kind box with value 'Unit_Cost'
# Out:
# <Axes: >

# %%
ax = sales['Unit_Cost'].plot(kind='kde', figsize=(14,6))  #kind kde chart describes the mean and median in the sales.
ax.axvline(sales['Unit_Cost'].mean(), color='red')
ax.axvline(sales['Unit_Cost'].median(), color='green')

# %%
ax = sales['Unit_Cost'].plot(kind='hist', figsize=(14,6))  #kind histogram chart describes  the number sales and quantity.
ax.set_ylabel('Number Sales')
ax.set_xlabel('Dollars')
# Out:
# Text(0.5, 0, 'Dollars')

# %%
sales['Age_Group'].value_counts()   #It shows a group of ages
# Out:
# Age_Group
# Adults (35-64)          55824
# Young Adults (25-34)    38654
# Youth (<25)             17828
# Seniors (64+)             730
# Name: count, dtype: int64

# %%
sales['Age_Group'].value_counts().plot(kind='pie', figsize=(6,6))    #kind pie what describes of group ages.
# Out:
# <Axes: ylabel='count'>

# %%
ax = sales['Age_Group'].value_counts().plot(kind='bar', figsize=(14,6))
ax.set_ylabel('Number of Sales')
# Out:
# Text(0, 0.5, 'Number of Sales')

# %%
sales['Customer_Age'].describe()
# Out:
# count    113036.000000
# mean         35.919212
# std          11.021936
# min          17.000000
# 25%          28.000000
# 50%          35.000000
# 75%          43.000000
# max          87.000000
# Name: Customer_Age, dtype: float64

# %%
sales['Customer_Age'].mean()
# Out:
# np.float64(35.91921157861212)

# %%
sales['Customer_Age'].median()
# Out:
# np.float64(35.0)

# %%
sales['Customer_Age'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %%
sales['Customer_Age'].plot(kind='kde', figsize=(14,6))
# Out:
# <Axes: ylabel='Density'>

# %%
sales['Order_Quantity'].mean()
# Out:
# np.float64(11.901659648253654)

# %% [markdown]
# Go ahead and show a histogram and a box plot with the Order_Quantity data:

# %%
sales['Order_Quantity'].plot(kind='hist', bins=30, figsize=(14,6))
# Out:
# <Axes: ylabel='Frequency'>

# %%
sales['Order_Quantity'].plot(kind='box', vert='False', figsize=(14,6))
# Out:
# <Axes: >

# %% [markdown]
# How many sales per year do we have?

# %%
sales['Year'].value_counts()
# Out:
# Year
# 2016    29398
# 2014    29398
# 2015    24443
# 2013    24443
# 2012     2677
# 2011     2677
# Name: count, dtype: int64

# %%
sales['Year'].value_counts().plot(kind='pie', figsize=(6,6))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# How many sales per month do we have?

# %%
sales['Month'].value_counts()
# Out:
# Month
# June         11234
# December     11200
# May          11128
# April        10182
# March         9674
# January       9284
# February      9022
# October       8750
# November      8734
# August        8200
# September     8166
# July          7462
# Name: count, dtype: int64

# %%
sales['Month'].value_counts().plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# Which country has the most sales quantity of sales?

# %%
sales['Country'].value_counts().head(1)   #It shows the first country what sold the most.
# Out:
# Country
# United States    39206
# Name: count, dtype: int64

# %%
sales['Country'].value_counts()
# Out:
# Country
# United States     39206
# Australia         23936
# Canada            14178
# United Kingdom    13620
# Germany           11098
# France            10998
# Name: count, dtype: int64

# %%
sales['Country'].value_counts().plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# Create a list of every product sold

# %%
sales['Product'].unique()
# Out:
# array(['Hitch Rack - 4-Bike', 'All-Purpose Bike Stand',
#        'Mountain Bottle Cage', 'Water Bottle - 30 oz.',
#        'Road Bottle Cage', 'AWC Logo Cap', 'Bike Wash - Dissolver',
#        'Fender Set - Mountain', 'Half-Finger Gloves, L',
#        'Half-Finger Gloves, M', 'Half-Finger Gloves, S',
#        'Sport-100 Helmet, Black', 'Sport-100 Helmet, Red',
#        'Sport-100 Helmet, Blue', 'Hydration Pack - 70 oz.',
#        'Short-Sleeve Classic Jersey, XL',
#        'Short-Sleeve Classic Jersey, L', 'Short-Sleeve Classic Jersey, M',
#        'Short-Sleeve Classic Jersey, S', 'Long-Sleeve Logo Jersey, M',
#        'Long-Sleeve Logo Jersey, XL', 'Long-Sleeve Logo Jersey, L',
#        'Long-Sleeve Logo Jersey, S', 'Mountain-100 Silver, 38',
#        'Mountain-100 Silver, 44', 'Mountain-100 Black, 48',
#        'Mountain-100 Silver, 48', 'Mountain-100 Black, 38',
#        'Mountain-200 Silver, 38', 'Mountain-100 Black, 44',
# ...

# %% [markdown]
# Create a bar plot showing the 10 most sold products (best sellers):]

# %%
sales['Product'].value_counts().head(10).plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='Product'>

# %% [markdown]
# Can you see any relationship between Unit_Cost and Unit_Price?

# %%
sales.plot(kind='scatter', x='Unit_Cost', y='Unit_Price', figsize=(6,6))   #It shows between Unit Cost and Unit Price
# Out:
# <Axes: xlabel='Unit_Cost', ylabel='Unit_Price'>

# %% [markdown]
# Can you see any relationship between Order_Quantity and Profit?

# %%
sales.plot(kind='scatter', x='Order_Quantity', y ='Profit', figsize=(6,6))
# Out:
# <Axes: xlabel='Order_Quantity', ylabel='Profit'>

# %% [markdown]
# Can you see any relationship between Profit per Country?

# %%
sales[['Profit', 'Country']].boxplot(by='Country', figsize=(10,6))
# Out:
# <Axes: title={'center': 'Profit'}, xlabel='[Country]'>

# %% [markdown]
# Add and calculate a new Calculated_Date column
#
# Use Day, Month, Year to create a Date column (YYYY-MM-DD).

# %%
sales['Calculated_Date'] = sales[['Year','Month','Day']].apply(lambda x: '{}-{}-{}'.format(x[0], x[1], x[2]), axis=1)
sales['Calculated_Date'].head()
# Out:
# C:\Users\hirva\AppData\Local\Temp\ipykernel_14556\3717859339.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sales['Calculated_Date'] = sales[['Year','Month','Day']].apply(lambda x: '{}-{}-{}'.format(x[0], x[1], x[2]), axis=1)
# 0    2013-November-26
# 1    2015-November-26
# 2       2014-March-23
# 3       2016-March-23
# 4         2014-May-15
# Name: Calculated_Date, dtype: object

# %%
sales['Calculated_Date'] = pd.to_datetime(sales['Calculated_Date'])   #parse type month name changed to number with pandas as pd
sales['Calculated_Date'].head()
# Out:
# 0   2013-11-26
# 1   2015-11-26
# 2   2014-03-23
# 3   2016-03-23
# 4   2014-05-15
# Name: Calculated_Date, dtype: datetime64[ns]

# %% [markdown]
# How did sales evolve through the years?

# %%
sales['Calculated_Date'].value_counts().plot(kind='line', figsize=(14,6))   #used the line plot for describing sales through the years
# Out:
# <Axes: xlabel='Calculated_Date'>

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  datetime64[ns]
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %% [markdown]
# Increase 50 U$S revenue to every sale

# %%
sales['Revenue']+= 50

# %%
sales['Revenue'].value_counts()
# Out:
# Revenue
# 35      824
# 20      783
# 10      763
# 5       754
# 30      752
#        ...
# 9923      1
# 7898      1
# 994       1
# 1309      1
# 1845      1
# Name: count, Length: 1876, dtype: int64

# %% [markdown]
# How many orders were made in Canada or France?

# %%
sales.loc[(sales['Country'] == 'Canada') | (sales['Country'] == 'France')].shape[0]   #shows the orders in Canada or France (comparative)
# Out:
# 25176

# %% [markdown]
# How many Bike Racks orders were made from Canada?

# %%
sales.loc[(sales['Country']=='Canada') & (sales['Sub_Category']=='Bike Racks')].shape[0]   #shows the subcategory Bike Racks in the country Canada the results is 104
# Out:
# 104

# %% [markdown]
# How many orders were made in each region (state) of France?

# %%
france_countries = sales.loc[sales['Country'] == 'France','State'].value_counts()
france_countries
# Out:
# State
# Seine (Paris)        2328
# Seine Saint Denis    1684
# Nord                 1670
# Hauts de Seine       1084
# Essonne               994
# Yveline               954
# Seine et Marne        394
# Moselle               386
# Loiret                382
# Val d'Oise            264
# Garonne (Haute)       208
# Val de Marne          158
# Charente-Maritime     148
# Somme                 134
# Loir et Cher          120
# Pas de Calais          90
# Name: count, dtype: int64

# %% [markdown]
# How many sales were made per category?

# %%
sales['Product_Category'].value_counts()
# Out:
# Product_Category
# Accessories    70120
# Bikes          25982
# Clothing       16934
# Name: count, dtype: int64

# %%
sales['Product_Category'].value_counts().plot(kind='pie', figsize=(6,6))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# How many orders were made per accessory sub-categories?

# %%
accessories = sales.loc[sales['Product_Category'] == 'Accessories', 'Sub_Category'].value_counts()
accessories
# Out:
# Sub_Category
# Tires and Tubes      33870
# Bottles and Cages    15876
# Helmets              12158
# Fenders               4032
# Cleaners              1802
# Hydration Packs       1334
# Bike Racks             592
# Bike Stands            456
# Name: count, dtype: int64

# %%
accessories.plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='Sub_Category'>

# %% [markdown]
# How many orders were made per bike sub-categories?

# %%
bikes = sales.loc[sales['Product_Category'] == 'Bikes', 'Sub_Category'].value_counts()
bikes
# Out:
# Sub_Category
# Road Bikes        13430
# Mountain Bikes     8854
# Touring Bikes      3698
# Name: count, dtype: int64

# %%
bikes.plot(kind='pie', figsize=(14,6))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Which gender has the most amount of sales?

# %%
sales['Customer_Gender'].value_counts()
# Out:
# Customer_Gender
# M    58312
# F    54724
# Name: count, dtype: int64

# %%
sales['Customer_Gender'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Customer_Gender'>

# %% [markdown]
# How many sales with more than 500 in Revenue were made by men?

# %%
sales.loc[(sales['Customer_Gender'] == 'M') & (sales['Revenue'] == 500)].shape[0]
# Out:
# 8

# %% [markdown]
# Get the top-5 sales with the highest revenue

# %%
sales.sort_values(['Revenue'], ascending=False).head(5)    #top 5 with the highest revenue
# Out:
#              Date  Day  Month  Year  Customer_Age             Age_Group  \
# 112073 2015-07-24   24   July  2015            52        Adults (35-64)
# 112072 2013-07-24   24   July  2013            52        Adults (35-64)
# 71129  2011-07-08    8   July  2011            22           Youth (<25)
# 59919  2011-03-20   20  March  2011            29  Young Adults (25-34)
# 68671  2011-07-05    5   July  2011            26  Young Adults (25-34)
#
#        Customer_Gender    Country             State Product_Category  \
# 112073               M  Australia        Queensland         Clothing
# 112072               M  Australia        Queensland         Clothing
# 71129                M     Canada           Alberta            Bikes
# 59919                F    Germany            Bayern            Bikes
# 68671                M     Canada  British Columbia            Bikes
#
#        Sub_Category                  Product  Order_Quantity  Unit_Cost  \
# ...

# %% [markdown]
# Get the sale with the highest revenue

# %%
sale = sales['Revenue'] == sales['Revenue'].max()  
sales.loc[sale]     #the answer is:
# Out:
#              Date  Day Month  Year  Customer_Age       Age_Group  \
# 112073 2015-07-24   24  July  2015            52  Adults (35-64)
#
#        Customer_Gender    Country       State Product_Category Sub_Category  \
# 112073               M  Australia  Queensland         Clothing        Vests
#
#                         Product  Order_Quantity  Unit_Cost  Unit_Price  \
# 112073  Touring-1000 Yellow, 50              29       1482        2384
#
#         Profit   Cost  Revenue
# 112073   15096  42978    58074

# %% [markdown]
# What is the mean Order_Quantity of orders with more than 10K in revenue?

# %%
cond = sales['Revenue'] > 10000
sales.loc[cond, 'Order_Quantity'].mean()  #the answer is 3.7221
# Out:
# np.float64(3.7218934911242605)

# %% [markdown]
# What is the mean Order_Quantity of orders with less than 10K in revenue?

# %%
cond2 = sales['Revenue'] < 10000 
sales.loc[cond2, 'Order_Quantity'].mean()   #the answer is 11.91
# Out:
# np.float64(11.913907519469818)

# %% [markdown]
# How many orders were made in May of 2016?

# %%
cond3 = (sales['Year'] == 2016) & (sales['Month'] == 'May')
sales.loc[cond3].shape[0]
# Out:
# 5015

# %% [markdown]
# How many orders were made between May and July of 2016?

# %%
cond4 = (sales['Year'] == 2016) & (sales['Month'].isin(['May','June','July']))
sales.loc[cond4].shape[0]
# Out:
# 12164

# %%
profit = sales.loc[sales['Year']==2016, ['Profit','Month']]
profit.boxplot(by='Month', figsize=(14,6))
# Out:
# <Axes: title={'center': 'Profit'}, xlabel='[Month]'>

# %% [markdown]
# Add 7.2% TAX on every sale Unit_Price within United States

# %%
sales.loc[sales['Country'] == 'United States', 'Unit_Price'] *=1.072
# Out:
# C:\Users\hirva\AppData\Local\Temp\ipykernel_24812\596740501.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[128.64  128.64  128.64  ...  68.608  68.608  68.608]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sales.loc[sales['Country'] == 'United States', 'Unit_Price'] *=1.072
